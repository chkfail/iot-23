# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Volumes/Unicorn/IoTScenarios/Experiment/pcap_detail.csv')
del df["Unnamed: 0"]
df
# Out:
#         pcap_row_id             detailed_label            ts  ip_version  \
# 0                 0                     Benign  1.526756e+09         4.0
# 1                 1                     Benign  1.526756e+09         4.0
# 2                 8                     Benign  1.526756e+09         4.0
# 3                34                     Benign  1.526756e+09         4.0
# 4                39  PartOfAHorizontalPortScan  1.526756e+09         4.0
# ...             ...                        ...           ...         ...
# 156099       496946  PartOfAHorizontalPortScan  1.526886e+09         4.0
# 156100       496949  PartOfAHorizontalPortScan  1.526886e+09         4.0
# 156101       496953  PartOfAHorizontalPortScan  1.526886e+09         4.0
# 156102       496956  PartOfAHorizontalPortScan  1.526886e+09         4.0
# 156103       496957  PartOfAHorizontalPortScan  1.526886e+09         4.0
#
#         ip_ihl  ip_tos  ip_len    ip_id ip_flags  ip_frag  ...  udp_dport  \
# ...

# %%
df.to_csv('/Volumes/Unicorn/IoTScenarios/Experiment/pcap.csv',index=False)

# %%
csv_list = ['/Volumes/Unicorn/IoTScenarios/Experiment/pcap_detail 2.csv',
            '/Volumes/Unicorn/IoTScenarios/Experiment/pcap_detail 3.csv',
            '/Volumes/Unicorn/IoTScenarios/Experiment/pcap_detail 4.csv',
            '/Volumes/Unicorn/IoTScenarios/Experiment/pcap_detail 5.csv',
            '/Volumes/Unicorn/IoTScenarios/Experiment/pcap_detail 6.csv']

for csv in csv_list:
    df = pd.read_csv(csv)
    del df["Unnamed: 0"]
    df.to_csv('/Volumes/Unicorn/IoTScenarios/Experiment/pcap.csv',index=False,header=False,mode='a+')

# %%
df = pd.read_csv('/Volumes/Unicorn/IoTScenarios/Experiment/pcap.csv')
df
# Out:
# /var/folders/11/1w8hy18j0r12wk4g7x6gd06h0000gn/T/ipykernel_28463/3856793663.py:1: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Volumes/Unicorn/IoTScenarios/Experiment/pcap.csv')
#         pcap_row_id             detailed_label            ts  ip_version  \
# 0                 0                     Benign  1.526756e+09         4.0
# 1                 1                     Benign  1.526756e+09         4.0
# 2                 8                     Benign  1.526756e+09         4.0
# 3                34                     Benign  1.526756e+09         4.0
# 4                39  PartOfAHorizontalPortScan  1.526756e+09         4.0
# ...             ...                        ...           ...         ...
# 200581        24366                     Benign  1.547156e+09         NaN
# 200582        24384                     Benign  1.547156e+09         4.0
# ...
