# %% [markdown]
# ## pcap
# ### bayes
# ```
#               precision    recall  f1-score   support
#
#       Attack   0.000000  0.000000  0.000000      1199
#       Benign   0.000000  0.000000  0.000000      3864
#          C&C   0.368649  1.000000  0.538705      2982
#         DDoS   1.000000  0.983275  0.991567      2870
#
#     accuracy                       0.531745     10915
#    macro avg   0.342162  0.495819  0.382568     10915
# weighted avg   0.363656  0.531745  0.407899     10915
# ```
# ### glm
# ```
#               precision    recall  f1-score   support
#
#       Attack   0.000000  0.000000  0.000000      1199
#       Benign   1.000000  0.681159  0.810345      3864
#          C&C   0.554378  1.000000  0.713312      2982
#         DDoS   0.988292  1.000000  0.994112      2870
#
#     accuracy                       0.777279     10915
#    macro avg   0.635668  0.670290  0.629442     10915
# weighted avg   0.765328  0.777279  0.743140     10915
# ```
# ### rf
# ```
#               precision    recall  f1-score   support
#
#       Attack   0.767224  0.956631  0.851522      1199
#       Benign   0.985410  0.908903  0.945611      3864
#          C&C   1.000000  1.000000  1.000000      2982
#         DDoS   0.998608  1.000000  0.999304      2870
#
#     accuracy                       0.962987     10915
#    macro avg   0.937810  0.966383  0.949109     10915
# weighted avg   0.968899  0.962987  0.964253     10915
# ```
# ### gbm
# ```
#               precision    recall  f1-score   support
#
#       Attack   0.734591  0.974145  0.837576      1199
#       Benign   0.990504  0.890787  0.938002      3864
#          C&C   1.000000  0.999329  0.999665      2982
#         DDoS   1.000000  1.000000  1.000000      2870
#
#     accuracy                       0.958314     10915
#    macro avg   0.931274  0.966065  0.943811     10915
# weighted avg   0.967483  0.958314  0.960119     10915
# ```
# ### xgboost
# ```
#               precision    recall  f1-score   support
#
#       Attack   0.750340  0.919933  0.826527      1199
#       Benign   0.973281  0.905021  0.937911      3864
#          C&C   1.000000  1.000000  1.000000      2982
#         DDoS   1.000000  1.000000  1.000000      2870
#
#     accuracy                       0.957581     10915
#    macro avg   0.930905  0.956238  0.941109     10915
# weighted avg   0.963117  0.957581  0.958964     10915
# ```
# ### ann
# ```
#               precision    recall  f1-score   support
#
#       Attack   0.683333  0.820684  0.745737      1199
#       Benign   0.999397  0.857919  0.923270      3864
#          C&C   0.908260  0.999329  0.951621      2982
#         DDoS   0.997567  1.000000  0.998782      2870
#
#     accuracy                       0.929821     10915
#    macro avg   0.897139  0.919483  0.904852     10915
# weighted avg   0.939298  0.929821  0.931369     10915
# ```
# ## zeek
# ### bayes
# ```
#               precision    recall  f1-score   support
#
#       Attack   0.988841  0.977929  0.983355      1178
#       Benign   0.996895  0.733689  0.845276      3939
#          C&C   0.614087  0.417116  0.496790      2968
#         DDoS   0.584152  0.990969  0.735025      2879
#
#     accuracy                       0.741791     10964
#    macro avg   0.795994  0.779926  0.765111     10964
# weighted avg   0.784022  0.741791  0.736825     10964
# ```
# ### glm
# ```
#               precision    recall  f1-score   support
#
#       Attack   0.994093  1.000000  0.997038      1178
#       Benign   0.991101  0.904798  0.945985      3939
#          C&C   0.883378  0.990229  0.933757      2968
#         DDoS   0.997899  0.989927  0.993897      2879
#
#     accuracy                       0.960507     10964
#    macro avg   0.966618  0.971239  0.967669     10964
# weighted avg   0.964047  0.960507  0.960741     10964
# ```
# ### rf
# ```
#               precision    recall  f1-score   support
#
#       Attack   1.000000  0.996604  0.998299      1178
#       Benign   0.998725  0.994161  0.996438      3939
#          C&C   0.991976  0.999663  0.995805      2968
#         DDoS   0.998610  0.998263  0.998437      2879
#
#     accuracy                       0.996990     10964
#    macro avg   0.997328  0.997173  0.997245     10964
# weighted avg   0.997005  0.996990  0.996991     10964
# ```
# ### gbm
# ```
#               precision    recall  f1-score   support
#
#       Attack   1.000000  0.996604  0.998299      1178
#       Benign   0.998731  0.999238  0.998985      3939
#          C&C   0.999663  0.999663  0.999663      2968
#         DDoS   0.999306  1.000000  0.999653      2879
#
#     accuracy                       0.999270     10964
#    macro avg   0.999425  0.998876  0.999150     10964
# weighted avg   0.999271  0.999270  0.999270     10964
# ```
# ### xgboost
# ```
#               precision    recall  f1-score   support
#
#       Attack   1.000000  0.999151  0.999575      1178
#       Benign   0.999492  0.999746  0.999619      3939
#          C&C   0.999663  0.999663  0.999663      2968
#         DDoS   1.000000  1.000000  1.000000      2879
#
#     accuracy                       0.999726     10964
#    macro avg   0.999789  0.999640  0.999714     10964
# weighted avg   0.999726  0.999726  0.999726     10964
# ```
# ### ann
# ```
#               precision    recall  f1-score   support
#
#       Attack   1.000000  1.000000  1.000000      1178
#       Benign   0.999744  0.993145  0.996434      3939
#          C&C   0.990982  0.999663  0.995304      2968
#         DDoS   0.997569  0.997569  0.997569      2879
#
#     accuracy                       0.996808     10964
#    macro avg   0.997074  0.997594  0.997327     10964
# weighted avg   0.996829  0.996808  0.996809     10964
# ```

# %%
# # pcap
# models = ['bayes','GLM','RF','GBM','XGBoost','ANN']
# accuracy = [0.531745,0.777279,0.962987,0.958314,0.957581,0.929821]
# weighted_f1_avg = [0.407899,0.743140,0.964253,0.960119,0.958964,0.931369]

# # zeek
# models = ['bayes','glm','RF','GBM','XGBoost','ANN']
# accuracy = [0.741791,0.960507,0.996990,0.999270,0.999726,0.996808]
# weighted_f1_avg = [0.736825,0.960741,0.996991,0.999270,0.999726,0.996809]

# %%
import matplotlib.pyplot as plt

models = ['RF','GBM','XGBoost','ANN']
accuracy = [0.996990,0.999270,0.999726,0.996808]
weighted_f1_avg = [0.996991,0.999270,0.999726,0.996809]

plt.figure(figsize=(8,6))
plt.scatter(accuracy, weighted_f1_avg, s=200, color="red")
plt.xlabel("Accuracy",fontsize=14)
plt.ylabel("Weighted F1 avg",fontsize=14)
plt.title("Zeek",fontsize=16)
for i, label in enumerate(models):
    plt.annotate(label, (accuracy[i], weighted_f1_avg[i]),fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt

models = ['RF','GBM','XGBoost','ANN']
accuracy = [0.962987,0.958314,0.957581,0.929821]
weighted_f1_avg = [0.964253,0.960119,0.958964,0.931369]

plt.figure(figsize=(8,6))
plt.scatter(accuracy, weighted_f1_avg, s=200, color="red")
plt.xlabel("Accuracy",fontsize=14)
plt.ylabel("Weighted F1 avg",fontsize=14)
plt.title("pcap",fontsize=16)
for i, label in enumerate(models):
    plt.annotate(label, (accuracy[i], weighted_f1_avg[i]),fontsize=14)
plt.show()
