# %%
import numpy as np
import pandas as pd
import json,os
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import h2o
from h2o.automl import H2OAutoML
from h2o.estimators import H2OGradientBoostingEstimator
from h2o.estimators import H2OSupportVectorMachineEstimator
from h2o.estimators import H2ODeepLearningEstimator
from h2o.estimators import H2OSupportVectorMachineEstimator
from h2o.estimators import H2OXGBoostEstimator
from h2o.estimators import H2ONaiveBayesEstimator
from h2o.estimators import H2ODeepLearningEstimator
from h2o.estimators import H2OGeneralizedLinearEstimator
from h2o.estimators import H2ORandomForestEstimator

# %%
h2o.init(ip="localhost",port=54321)
m_models = {
    "bayes":H2ONaiveBayesEstimator(),
    "glm":H2OGeneralizedLinearEstimator(nfolds = 4),
    "rf":H2ORandomForestEstimator(nfolds = 4),
    "gbm":H2OGradientBoostingEstimator(nfolds=4),
    #"svm":H2OSupportVectorMachineEstimator(),
    "xgboost":H2OXGBoostEstimator(nfolds=4),
    "ann":H2ODeepLearningEstimator(nfolds=4)
}
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# Warning: Your H2O cluster version is too old (7 months and 7 days)!Please download and install the latest version from http://h2o.ai/download/
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         39 days 17 hours 45 mins
# H2O_cluster_timezone:       Asia/Shanghai
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.34.0.3
# H2O_cluster_version_age:    7 months and 7 days !!!
# H2O_cluster_name:           root
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    19.93 Gb
# H2O_cluster_total_cores:    20
# H2O_cluster_allowed_cores:  20
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.8.10 final
# --------------------------  ------------------------------------------------------------------

# %%
df_raw = pd.read_csv('./zeek.csv')
del df_raw['ts']
del df_raw['uid']
del df_raw['id.orig_h']
del df_raw['id.resp_h']
del df_raw['tunnel_parents']
del df_raw['service']
del df_raw['local_orig']
del df_raw['label']

df_raw['detailed-label'] = df_raw['detailed-label'].replace(to_replace= '-',value= 'Benign')
df_raw['proto'] = df_raw['proto'].map({"tcp":6,"udp":17,"icmp":1})
df_raw['detailed-label'].value_counts()
# Out:
# PartOfAHorizontalPortScan    145719
# Benign                        19525
# C&C                           14936
# DDoS                          14394
# Attack                         5962
# C&C-Torii                        30
# C&C-FileDownload                  3
# FileDownload                      2
# Name: detailed-label, dtype: int64

# %%
df_input = df_raw[(df_raw['detailed-label']=="Attack")|(df_raw['detailed-label']=="Benign")|(df_raw['detailed-label']=="C&C")|(df_raw['detailed-label']=="DDoS")]
df_input['detailed-label'].value_counts()
# Out:
# Benign    19525
# C&C       14936
# DDoS      14394
# Attack     5962
# Name: detailed-label, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df_input, df_input['detailed-label'], test_size=0.20)
X_train
# Out:
#         id.orig_p  id.resp_p  proto  duration orig_bytes resp_bytes  \
# 156116        123        123     17  0.001734         48         48
# 192937      65279         80      6         -          -          -
# 156234      43332         50      6  3.117974          0          0
# 176928        123        123     17         -          -          -
# 159558      44668         50      6         -          -          -
# ...           ...        ...    ...       ...        ...        ...
# 93301          11          0      1         -          -          -
# 193134      65279         80      6         -          -          -
# 68444         123        123     17  0.124131         48         48
# 190957      65279         80      6         -          -          -
# 164052      46460         50      6  3.084496          0          0
#
#        conn_state local_resp  missed_bytes history  orig_pkts  orig_ip_bytes  \
# 156116         SF          -             0      Dd          1             76
# 192937        OTH          -             0       C          0              0
# 156234         S0          -             0       S          3            180
# 176928         S0          -             0       D          1             76
# 159558         S0          -             0       S          1             60
# ...           ...        ...           ...     ...        ...            ...
# 93301         OTH          -             0       -          1             56
# 193134        OTH          -             0       C          0              0
# 68444          SF          -             0      Dd          1             76
# 190957        OTH          -             0       C          0              0
# 164052         S0          -             0       S          3            180
#
#         resp_pkts  resp_ip_bytes detailed-label
# 156116          1             76         Benign
# 192937          0              0           DDoS
# 156234          0              0            C&C
# 176928          0              0         Benign
# 159558          0              0            C&C
# ...           ...            ...            ...
# 93301           0              0         Benign
# 193134          0              0           DDoS
# 68444           1             76         Benign
# 190957          0              0           DDoS
# 164052          0              0            C&C
#
# [43853 rows x 15 columns]

# %%
def Train(df_all):
    df_h2o = h2o.H2OFrame(df_all)
    df_train, df_valid = df_h2o.split_frame(ratios=[0.85], seed=1234)
    x = df_train.columns
    y = "detailed-label"
    x.remove(y)
    df_train[y] = df_train[y].asfactor()
    df_valid[y] = df_valid[y].asfactor()
    for key in m_models:
        print("begin train ",key)
        m_models[key].train(x=x, y=y,training_frame=df_train,validation_frame=df_valid)
        print("end train ",key)

def Predict( df_all ):
    df_h2o = h2o.H2OFrame(df_all)
    x = df_h2o.columns
    y = "detailed-label"
    x.remove(y)
    df_h2o[y] = df_h2o[y].asfactor()
    ret = {}
    for key in m_models:
        pred = m_models[key].predict(df_h2o).as_data_frame()
        y_true = df_all[y].to_list()
        y_pred = pred['predict']
        ret[key] = {}
        ret[key]['y_pred'] = y_pred.to_list()
        ret[key]['y_true'] = y_true
    return ret

# %%
Train(X_train)
result = Predict(X_test)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# begin train  bayes
# naivebayes Model Build progress: |
# /data/env/ai/lib/python3.8/site-packages/h2o/estimators/estimator_base.py:206: RuntimeWarning: Dropping bad and constant columns: [local_resp]
#   warnings.warn(mesg["message"], RuntimeWarning)
# ███████████████████████████████████████████████| (done) 100%
# end train  bayes
# begin train  glm
# glm Model Build progress: |██████████████████████████████████████████████████████| (done) 100%
# end train  glm
# begin train  rf
# drf Model Build progress: |
# /data/env/ai/lib/python3.8/site-packages/h2o/job.py:83: UserWarning: Reached maximum number of iterations 50!
#   warnings.warn(w)
# ██████████████████████████████████████████████████████| (done) 100%
# end train  rf
# begin train  gbm
# gbm Model Build progress: |██████████████████████████████████████████████████████| (done) 100%
# end train  gbm
# begin train  xgboost
# xgboost Model Build progress: |██████████████████████████████████████████████████| (done) 100%
# end train  xgboost
# begin train  ann
# deeplearning Model Build progress: |█████████████████████████████████████████████| (done) 100%
# end train  ann
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# naivebayes prediction progress: |████████████████████████████████████████████████| (done) 100%
# glm prediction progress: |
# /data/env/ai/lib/python3.8/site-packages/h2o/job.py:83: UserWarning: Test/Validation dataset column 'history' has levels not trained on: ["DaFfA", "DdA", "SahAdDF", "ShADadFfR", "ShADadttfF", "ShAadDFRf", "ShAdDaFRRRf", "ShAdFaf"]
#   warnings.warn(w)
# ███████████████████████████████████████████████████████| (done) 100%
# drf prediction progress: |███████████████████████████████████████████████████████| (done) 100%
# gbm prediction progress: |███████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# deeplearning prediction progress: |██████████████████████████████████████████████| (done) 100%

# %%
from sklearn.metrics import classification_report
for model in result.keys():
    y_pred = result[model]['y_pred']
    y_true = result[model]['y_true']
    print(model)
    print(classification_report(y_true, y_pred, target_names=['Attack','Benign','C&C','DDoS'],digits=6))
# Out:
# bayes
#               precision    recall  f1-score   support
#
#       Attack   0.983663  0.976109  0.979872      1172
#       Benign   0.998570  0.703601  0.825528      3971
#          C&C   0.582552  0.417199  0.486201      2977
#         DDoS   0.579347  0.992264  0.731562      2844
#
#     accuracy                       0.729843     10964
#    macro avg   0.786033  0.772293  0.755791     10964
# weighted avg   0.775273  0.729843  0.725517     10964
#
# glm
#               precision    recall  f1-score   support
#
#       Attack   0.990702  1.000000  0.995329      1172
#       Benign   0.990677  0.909846  0.948543      3971
#          C&C   0.885414  0.988915  0.934307      2977
#         DDoS   0.998932  0.986639  0.992747      2844
#
#     accuracy                       0.960872     10964
#    macro avg   0.966431  0.971350  0.967731     10964
# weighted avg   0.964239  0.960872  0.961145     10964
#
# rf
#               precision    recall  f1-score   support
#
#       Attack   0.998296  1.000000  0.999147      1172
#       Benign   1.000000  0.994208  0.997096      3971
#          C&C   0.982502  0.999664  0.991009      2977
#         DDoS   1.000000  0.989100  0.994520      2844
#
#     accuracy                       0.994984     10964
#    macro avg   0.995200  0.995743  0.995443     10964
# weighted avg   0.995067  0.994984  0.994994     10964
#
# gbm
#               precision    recall  f1-score   support
#
#       Attack   1.000000  0.996587  0.998291      1172
#       Benign   0.997987  0.998993  0.998490      3971
#          C&C   1.000000  0.999664  0.999832      2977
#         DDoS   0.998594  0.998945  0.998770      2844
#
#     accuracy                       0.998906     10964
#    macro avg   0.999145  0.998547  0.998845     10964
# weighted avg   0.998906  0.998906  0.998906     10964
#
# xgboost
#               precision    recall  f1-score   support
#
#       Attack   0.999147  1.000000  0.999574      1172
#       Benign   0.999748  0.999748  0.999748      3971
#          C&C   1.000000  1.000000  1.000000      2977
#         DDoS   1.000000  0.999648  0.999824      2844
#
#     accuracy                       0.999818     10964
#    macro avg   0.999724  0.999849  0.999786     10964
# weighted avg   0.999818  0.999818  0.999818     10964
#
# ann
#               precision    recall  f1-score   support
#
#       Attack   0.997447  1.000000  0.998722      1172
#       Benign   0.999747  0.993956  0.996843      3971
#          C&C   0.988372  0.999328  0.993820      2977
#         DDoS   0.998587  0.994023  0.996300      2844
#
#     accuracy                       0.996078     10964
#    macro avg   0.996038  0.996827  0.996421     10964
# weighted avg   0.996112  0.996078  0.996082     10964

# %%
for key in m_models:
    print(key)
    varimp = m_models[key].varimp(use_pandas=True)
    display(varimp)
# Out:
# bayes
# Warning: This model doesn't have variable importances
# None
# glm
#            variable  relative_importance  scaled_importance  percentage
# 0     conn_state.SF             5.477256           1.000000    0.130086
# 1         history.C             5.117614           0.934339    0.121545
# 2    conn_state.OTH             4.108648           0.750129    0.097581
# 3         history.S             3.603069           0.657824    0.085574
# 4         history.-             3.249228           0.593222    0.077170
# ..              ...                  ...                ...         ...
# 109   conn_state.S2             0.000000           0.000000    0.000000
# 110   conn_state.SH             0.000000           0.000000    0.000000
# 111  conn_state.SHR             0.000000           0.000000    0.000000
# 112      orig_bytes             0.000000           0.000000    0.000000
# 113   orig_ip_bytes             0.000000           0.000000    0.000000
#
# [114 rows x 4 columns]
# rf
#          variable  relative_importance  scaled_importance  percentage
# 0         history        420364.062500           1.000000    0.390739
# 1       id.orig_p        201310.250000           0.478895    0.187123
# 2      conn_state        154858.921875           0.368392    0.143945
# 3       id.resp_p        101601.226562           0.241698    0.094441
# 4           proto         80541.390625           0.191599    0.074865
# 5   resp_ip_bytes         66421.546875           0.158010    0.061740
# 6      resp_bytes         24911.839844           0.059263    0.023156
# 7       resp_pkts         22012.664062           0.052366    0.020461
# 8       orig_pkts          1162.718018           0.002766    0.001081
# 9   orig_ip_bytes          1040.612671           0.002476    0.000967
# 10     orig_bytes           961.824951           0.002288    0.000894
# 11       duration           614.247192           0.001461    0.000571
# 12   missed_bytes            18.006281           0.000043    0.000017
# gbm
#          variable  relative_importance  scaled_importance    percentage
# 0         history        108883.335938       1.000000e+00  9.028162e-01
# 1       id.resp_p         10407.068359       9.557999e-02  8.629117e-02
# 2       id.orig_p          1277.064575       1.172874e-02  1.058890e-02
# 3       orig_pkts            31.567335       2.899189e-04  2.617435e-04
# 4      conn_state             3.144727       2.888162e-05  2.607480e-05
# 5   orig_ip_bytes             1.408436       1.293528e-05  1.167818e-05
# 6      resp_bytes             0.309832       2.845544e-06  2.569004e-06
# 7        duration             0.107574       9.879762e-07  8.919609e-07
# 8   resp_ip_bytes             0.046735       4.292206e-07  3.875073e-07
# 9       resp_pkts             0.036663       3.367182e-07  3.039946e-07
# 10     orig_bytes             0.005921       5.437923e-08  4.909445e-08
# 11          proto             0.000604       5.545178e-09  5.006277e-09
# 12   missed_bytes             0.000001       1.289673e-11  1.164337e-11
# xgboost
#              variable  relative_importance  scaled_importance    percentage
# 0       orig_ip_bytes         51035.972656       1.000000e+00  2.758443e-01
# 1           history.S         38142.597656       7.473669e-01  2.061569e-01
# 2               proto         30682.765625       6.011988e-01  1.658373e-01
# 3          resp_bytes         27603.279297       5.408593e-01  1.491929e-01
# 4           id.resp_p         22043.451172       4.319199e-01  1.191426e-01
# 5       resp_ip_bytes         10209.879883       2.000526e-01  5.518337e-02
# 6           id.orig_p          2797.165771       5.480773e-02  1.511840e-02
# 7       conn_state.SF          1025.716797       2.009792e-02  5.543896e-03
# 8     conn_state.RSTO           507.952515       9.952833e-03  2.745432e-03
# 9          orig_bytes           252.908798       4.955501e-03  1.366947e-03
# 10     history.ShAfFa           223.725464       4.383682e-03  1.209214e-03
# 11   history.ShAdDaFf           187.732483       3.678435e-03  1.014675e-03
# 12          orig_pkts            95.912453       1.879311e-03  5.183972e-04
# 13          resp_pkts            50.021149       9.801155e-04  2.703593e-04
# 14      conn_state.S2            48.212700       9.446807e-04  2.605848e-04
# 15          history.C            41.413357       8.114542e-04  2.238350e-04
# 16     history.ShADad            28.160431       5.517761e-04  1.522043e-04
# 17      conn_state.S3            14.705509       2.881401e-04  7.948180e-05
# 18           duration            13.379282       2.621540e-04  7.231367e-05
# 19        history.^aA             6.723180       1.317341e-04  3.633811e-05
# 20    history.ShAdfDr             1.591655       3.118692e-05  8.602734e-06
# 21    conn_state.RSTR             1.495953       2.931174e-05  8.085477e-06
# 22      conn_state.S0             0.803692       1.574756e-05  4.343875e-06
# 23      conn_state.S1             0.712891       1.396839e-05  3.853102e-06
# 24          history.-             0.561264       1.099742e-05  3.033576e-06
# 25    history.ShAdDaR             0.252190       4.941425e-06  1.363064e-06
# 26          history.D             0.116269       2.278179e-06  6.284226e-07
# 27         history.Dd             0.105545       2.068057e-06  5.704618e-07
# 28  history.ShAdDaFRR             0.006884       1.348778e-07  3.720528e-08
# ann
#                    variable  relative_importance  scaled_importance  \
# 0                 history.C             1.000000           1.000000
# 1             conn_state.SF             0.771778           0.771778
# 2                     proto             0.762397           0.762397
# 3                 id.resp_p             0.692013           0.692013
# 4                 history.S             0.671785           0.671785
# ..                      ...                  ...                ...
# 111           history.ShAdD             0.391556           0.391556
# 112         history.ShAdfFa             0.391172           0.391172
# 113       history.ShAdDtaFf             0.382218           0.382218
# 114     history.missing(NA)             0.000000           0.000000
# 115  conn_state.missing(NA)             0.000000           0.000000
#
#      percentage
# 0      0.019042
# 1      0.014696
# 2      0.014518
# 3      0.013178
# 4      0.012792
# ..          ...
# 111    0.007456
# 112    0.007449
# 113    0.007278
# 114    0.000000
# 115    0.000000
#
# [116 rows x 4 columns]

# %%
varimp = m_models['rf'].varimp(use_pandas=True)
varimp['scaled_importance'].tolist()
# Out:
# [1.0,
#  0.4788950054454286,
#  0.3683923905245825,
#  0.24169817457337947,
#  0.19159913467864537,
#  0.15800957503354607,
#  0.0592625347076381,
#  0.05236571349983087,
#  0.0027659786392375658,
#  0.0024755034117561786,
#  0.0022880760678058083,
#  0.001461226701278282,
#  4.283496736605035e-05]

# %%
f1 = [0.961145,0.994994,0.998906,0.999818,0.996082]

p = []
i = 0
for key in m_models:
    print(key)
    if key != 'bayes':
        # varimp.append(m_models[key].varimp())
        varimp = m_models[key].varimp(use_pandas=True)
        del varimp['percentage']
        del varimp['relative_importance']
        varimp['scaled_importance'] = varimp['scaled_importance'] * f1[i]
        p += varimp.values.tolist()
        i +=1 

p
# Out:
# bayes
# glm
# rf
# gbm
# xgboost
# ann
# [['conn_state.SF', 0.961145],
#  ['history.C', 0.8980352696785605],
#  ['conn_state.OTH', 0.7209826309103673],
#  ['history.S', 0.6322639844256431],
#  ['history.-', 0.5701722447529903],
#  ['proto', 0.5483592890350075],
#  ['history.ShAdDaFf', 0.5100801714065508],
#  ['id.resp_p', 0.3513647523243964],
#  ['id.orig_p', 0.321457574395354],
#  ['conn_state.S0', 0.3213654900036895],
#  ['conn_state.S3', 0.2903628592490466],
#  ['conn_state.REJ', 0.2644587165933583],
#  ['history.Sr', 0.2644587165933583],
#  ['history.Dd', 0.20814011602274313],
#  ['history.ShAdDaf', 0.1428929484065529],
#  ['resp_bytes', 0.07770615756806408],
#  ['missed_bytes', 0.05736467988748645],
#  ['orig_pkts', 0.054011480735431466],
#  ['resp_ip_bytes', 0.052359803249844517],
#  ['resp_pkts', 0.03540644336529867],
#  ['history.D', 0.03435520495867405],
#  ['history.ShAdDaFRfR', 0.022958861983416623],
#  ['conn_state.RSTO', 0.02071658377426368],
#  ['duration', 0.015435317989673361],
#  ['history.ShAdDaft', 0.012666885841346703],
#  ['history.Aa', 0.0],
#  ['history.CCC', 0.0],
#  ['history.CCCC', 0.0],
#  ['history.DFafA', 0.0],
#  ['history.D^d', 0.0],
#  ['history.DdAa', 0.0],
#  ['history.DdAtaFf', 0.0],
#  ['history.F', 0.0],
#  ['history.SahAdDFRf', 0.0],
#  ['history.SahAdDFf', 0.0],
#  ['history.SahAdDtFf', 0.0],
#  ['history.ShAD', 0.0],
#  ['history.ShADF', 0.0],
#  ['history.ShADFa', 0.0],
#  ['history.ShADFaR', 0.0],
#  ['history.ShADFadfR', 0.0],
#  ['history.ShADFar', 0.0],
#  ['history.ShADFfR', 0.0],
#  ['history.ShADFfa', 0.0],
#  ['history.ShADFr', 0.0],
#  ['history.ShADa', 0.0],
#  ['history.ShADaR', 0.0],
#  ['history.ShADacdtfF', 0.0],
#  ['history.ShADad', 0.0],
#  ['history.ShADadFf', 0.0],
#  ['history.ShADadRf', 0.0],
#  ['history.ShADadf', 0.0],
#  ['history.ShADadfrr', 0.0],
#  ['history.ShADadtFf', 0.0],
#  ['history.ShADadtcfF', 0.0],
#  ['history.ShADadtctfF', 0.0],
#  ['history.ShADadtctfFR', 0.0],
#  ['history.ShADadttcfF', 0.0],
#  ['history.ShADdaf', 0.0],
#  ['history.ShAa', 0.0],
#  ['history.ShAadDFR', 0.0],
#  ['history.ShAadDFf', 0.0],
#  ['history.ShAadDr', 0.0],
#  ['history.ShAafF', 0.0],
#  ['history.ShAdD', 0.0],
#  ['history.ShAdDFaf', 0.0],
#  ['history.ShAdDFf', 0.0],
#  ['history.ShAdDa', 0.0],
#  ['history.ShAdDaF', 0.0],
#  ['history.ShAdDaFR', 0.0],
#  ['history.ShAdDaFRR', 0.0],
#  ['history.ShAdDaFRRf', 0.0],
#  ['history.ShAdDaFRRfR', 0.0],
#  ['history.ShAdDaFRf', 0.0],
#  ['history.ShAdDaFRfRR', 0.0],
#  ['history.ShAdDaFRr', 0.0],
#  ['history.ShAdDaFT', 0.0],
#  ['history.ShAdDaFTf', 0.0],
#  ['history.ShAdDaFfR', 0.0],
#  ['history.ShAdDaFfRR', 0.0],
#  ['history.ShAdDaFfr', 0.0],
#  ['history.ShAdDaFr', 0.0],
#  ['history.ShAdDaFrR', 0.0],
#  ['history.ShAdDaR', 0.0],
#  ['history.ShAdDaTFRf', 0.0],
#  ['history.ShAdDaTFf', 0.0],
#  ['history.ShAdDafF', 0.0],
#  ['history.ShAdDar', 0.0],
#  ['history.ShAdDatFf', 0.0],
#  ['history.ShAdDatR', 0.0],
#  ['history.ShAdDatf', 0.0],
#  ['history.ShAdDatfr', 0.0],
#  ['history.ShAdDfr', 0.0],
#  ['history.ShAdDtaFf', 0.0],
#  ['history.ShAdfDr', 0.0],
#  ['history.ShAdfFa', 0.0],
#  ['history.ShAfFa', 0.0],
#  ['history.ShAfdtDr', 0.0],
#  ['history.ShAr', 0.0],
#  ['history.ShArR', 0.0],
#  ['history.ShDadAf', 0.0],
#  ['history.ShR', 0.0],
#  ['history.^aA', 0.0],
#  ['history.^d', 0.0],
#  ['history.^dDA', 0.0],
#  ['history.^r', 0.0],
#  ['conn_state.RSTR', 0.0],
#  ['conn_state.RSTRH', 0.0],
#  ['conn_state.S1', 0.0],
#  ['conn_state.S2', 0.0],
#  ['conn_state.SH', 0.0],
#  ['conn_state.SHR', 0.0],
#  ['orig_bytes', 0.0],
#  ['orig_ip_bytes', 0.0],
#  ['history', 0.994994],
#  ['id.orig_p', 0.4764976570481688],
#  ['conn_state', 0.36654821821761646],
#  ['id.resp_p', 0.24048823351146514],
#  ['proto', 0.19063998941044408],
#  ['resp_ip_bytes', 0.15721857910092815],
#  ['resp_bytes', 0.058965866458891666],
#  ['resp_pkts', 0.05210357073805072],
#  ['orig_pkts', 0.0027521321501695426],
#  ['orig_ip_bytes', 0.002463111041676927],
#  ['orig_bytes', 0.0022766219590103724],
#  ['duration', 0.001453911800411683],
#  ['missed_bytes', 4.26205355194159e-05],
#  ['history', 0.998906],
#  ['id.resp_p', 0.09547542731935635],
#  ['id.orig_p', 0.011715910938679297],
#  ['orig_pkts', 0.00028960171170961735],
#  ['conn_state', 2.885002658665049e-05],
#  ['orig_ip_bytes', 1.292112643195135e-05],
#  ['resp_bytes', 2.842431351403855e-06],
#  ['duration', 9.868953359899642e-07],
#  ['resp_ip_bytes', 4.287510602516256e-07],
#  ['resp_pkts', 3.3634981793809e-07],
#  ['orig_bytes', 5.431973727916929e-08],
#  ['proto', 5.53911205288546e-09],
#  ['missed_bytes', 1.288261603554008e-11],
#  ['orig_ip_bytes', 0.999818],
#  ['history.S', 0.7472308984946203],
#  ['proto', 0.6010893839190785],
#  ['resp_bytes', 0.5407608411018148],
#  ['id.resp_p', 0.43184127031745145],
#  ['resp_ip_bytes', 0.20001620726285357],
#  ['id.orig_p', 0.054797754245827605],
#  ['conn_state.SF', 0.020094260245128875],
#  ['conn_state.RSTO', 0.009951021619817754],
#  ['orig_bytes', 0.004954598798765748],
#  ['history.ShAfFa', 0.004382883957936494],
#  ['history.ShAdDaFf', 0.0036777650317845086],
#  ['orig_pkts', 0.0018789687281411957],
#  ['resp_pkts', 0.0009799371351151462],
#  ['conn_state.S2', 0.0009445087978127039],
#  ['history.C', 0.0008113065627054539],
#  ['history.ShADad', 0.000551675695482799],
#  ['conn_state.S3', 0.000288087637364126],
#  ['duration', 0.0002621062413849954],
#  ['history.^aA', 0.00013171016145314493],
#  ['history.ShAdfDr', 3.118124594711836e-05],
#  ['conn_state.RSTR', 2.930640840386215e-05],
#  ['conn_state.S0', 1.5744695136543146e-05],
#  ['conn_state.S1', 1.3965852746787289e-05],
#  ['history.-', 1.0995418698310718e-05],
#  ['history.ShAdDaR', 4.940525850878486e-06],
#  ['history.D', 2.277764092841286e-06],
#  ['history.Dd', 2.0676808421025895e-06],
#  ['history.ShAdDaFRR', 1.3485328168652432e-07],
#  ['history.C', 0.996082],
#  ['conn_state.SF', 0.76875422069633],
#  ['proto', 0.7594100385833978],
#  ['id.resp_p', 0.6893020744774342],
#  ['history.S', 0.6691534183371067],
#  ['duration', 0.6362849166678191],
#  ['conn_state.OTH', 0.6357451145013571],
#  ['history.Dd', 0.6203468599165678],
#  ['resp_pkts', 0.619455046416521],
#  ['id.orig_p', 0.6136706375434399],
#  ['conn_state.S0', 0.5959946695497036],
#  ['missed_bytes', 0.5882390803281069],
#  ['history.-', 0.5724055761082173],
#  ['resp_bytes', 0.5660690158770084],
#  ['history.D', 0.5553018862801791],
#  ['resp_ip_bytes', 0.5406768217101098],
#  ['orig_bytes', 0.5212612207115889],
#  ['orig_ip_bytes', 0.520705388344407],
#  ['history.ShAdDaFf', 0.5074238327080012],
#  ['conn_state.S1', 0.49440653789901734],
#  ['history.ShADad', 0.4828749458411932],
#  ['conn_state.REJ', 0.4727854187659025],
#  ['conn_state.S3', 0.47210662882208826],
#  ['history.CCCC', 0.46645055061143637],
#  ['conn_state.RSTRH', 0.46119680075329544],
#  ['history.ShAdDaFR', 0.45486234819662574],
#  ['conn_state.RSTO', 0.45423105514383316],
#  ['history.F', 0.45328545141470433],
#  ['history.ShAdDaTFRf', 0.4493161065464616],
#  ['history.ShADadtctfFR', 0.4477039433229566],
#  ['history.ShADa', 0.44727148413020373],
#  ['history.ShADFr', 0.4460946892840266],
#  ['history.ShAa', 0.4455241922517419],
#  ['history.ShAdDaFRf', 0.44472152447903157],
#  ['history.^d', 0.44346342089253665],
#  ['history.ShAdDaFrR', 0.4427414384634495],
#  ['history.Sr', 0.442032606736064],
#  ['history.ShADFadfR', 0.44197727285802363],
#  ['history.ShAdDaFfR', 0.441075574067533],
#  ['history.ShAdfDr', 0.4410325003244877],
#  ['history.ShAadDFf', 0.4410202698750496],
#  ['history.ShAdDaft', 0.44100887062120436],
#  ['history.ShADFfR', 0.44044716051375865],
#  ['history.ShAdDafF', 0.43670464298570155],
#  ['history.ShAdDaFRfRR', 0.43651085567033293],
#  ['orig_pkts', 0.4359200240315795],
#  ['history.ShADadFf', 0.4353281830838919],
#  ['history.ShADadtcfF', 0.434321041195333],
#  ['history.DdAa', 0.4335798522109389],
#  ['history.ShAdDaFRR', 0.4332669664413333],
#  ['history.DdAtaFf', 0.4323988420156837],
#  ['history.ShADadtFf', 0.43207342894107104],
#  ['history.ShAdDaF', 0.4315053661244512],
#  ['history.ShAadDFR', 0.4313805086721778],
#  ['history.SahAdDFRf', 0.430317409508884],
#  ['history.^r', 0.4302790557693839],
#  ['history.ShAr', 0.4293953167408109],
#  ['history.ShR', 0.42783777494198083],
#  ['history.ShAdDFaf', 0.42730539416474106],
#  ['history.Aa', 0.4262769083607793],
#  ['history.ShAdDaTFf', 0.42603452578878404],
#  ['history.CCC', 0.42501470816743375],
#  ['conn_state.SHR', 0.424912055511713],
#  ['history.SahAdDFf', 0.42481795229637626],
#  ['history.ShAdDFf', 0.4248087794592977],
#  ['history.ShAfFa', 0.4247030988767743],
#  ['history.ShAdDaFr', 0.42414221996492146],
#  ['history.ShAdDfr', 0.42406022845679525],
#  ['history.ShADFfa', 0.42346562675231697],
#  ['history.ShADaR', 0.4220989333987236],
#  ['history.ShADadRf', 0.4200901117640734],
#  ['history.ShAdDaFRr', 0.4193973399229646],
#  ['history.ShADFar', 0.4189744394795299],
#  ['history.SahAdDtFf', 0.4183926025645137],
#  ['history.ShAdDaf', 0.4176841567493677],
#  ['history.DFafA', 0.41646025092440847],
#  ['history.ShADacdtfF', 0.41607496208155154],
#  ['history.ShADadtctfF', 0.41596530363440515],
#  ['history.ShAdDaFRRf', 0.41509709015208485],
#  ['history.ShAdDatfr', 0.4149161566828489],
#  ['history.ShAD', 0.414303357731998],
#  ['history.ShAdDatR', 0.4141397903135419],
#  ['history.ShAdDaFRRfR', 0.4141098079010844],
#  ['conn_state.SH', 0.41315880140060185],
#  ['history.ShAadDr', 0.41307024938440323],
#  ['history.ShDadAf', 0.41202445690077544],
#  ['conn_state.RSTR', 0.4118889423335791],
#  ['history.ShADFa', 0.41035553489249943],
#  ['history.ShAdDaFTf', 0.4094373903034926],
#  ['history.ShAdDaR', 0.4083414292287231],
#  ['conn_state.S2', 0.40721866209608315],
#  ['history.ShAafF', 0.4071567083388567],
#  ['history.D^d', 0.40705838977444175],
#  ['history.ShADadfrr', 0.4070182252159715],
#  ['history.ShAdDa', 0.4068107528588772],
#  ['history.ShADFaR', 0.4061075910728574],
#  ['history.ShAdDatf', 0.40556933255535366],
#  ['history.ShAdDaFRfR', 0.4052890712127686],
#  ['history.ShAdDar', 0.4034644187730551],
#  ['history.ShAdDatFf', 0.4021194255615473],
#  ['history.ShAdDaFT', 0.4020567890365124],
#  ['history.ShArR', 0.40202781593298914],
#  ['history.^aA', 0.40133498472076656],
#  ['history.ShAdDaFfRR', 0.39896601790994407],
#  ['history.ShADdaf', 0.39822770842456817],
#  ['history.ShAfdtDr', 0.3965437655245066],
#  ['history.ShADF', 0.3949446936315894],
#  ['history.ShAdDaFfr', 0.39405893598514796],
#  ['history.^dDA', 0.3927648535037041],
#  ['history.ShADadf', 0.39175082456594706],
#  ['history.ShADadttcfF', 0.3916618272663951],
#  ['history.ShAdD', 0.3900220267894268],
#  ['history.ShAdfFa', 0.3896391424766779],
#  ['history.ShAdDtaFf', 0.3807206512495279],
#  ['history.missing(NA)', 0.0],
#  ['conn_state.missing(NA)', 0.0]]

# %%
# a = []
# for i in p:
#     if i[0] not in a:
#         a.append(i)
#     else:
#         a.index[]
        

a=pd.DataFrame(p) 
a
a.to_csv('a.csv',index=False)
