# %%
import numpy as np
import pandas as pd

# %%
pcap = pd.read_csv('./pcap.csv')
pcap
# Out:
# /var/folders/11/1w8hy18j0r12wk4g7x6gd06h0000gn/T/ipykernel_7918/1483983408.py:1: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   pcap = pd.read_csv('./pcap.csv')
#         pcap_row_id             detailed_label            ts  ip_version  \
# 0                 0                     Benign  1.526756e+09         4.0
# 1                 1                     Benign  1.526756e+09         4.0
# 2                 8                     Benign  1.526756e+09         4.0
# 3                34                     Benign  1.526756e+09         4.0
# 4                39  PartOfAHorizontalPortScan  1.526756e+09         4.0
# ...             ...                        ...           ...         ...
# 200581        24366                     Benign  1.547156e+09         NaN
# 200582        24384                     Benign  1.547156e+09         4.0
# 200583        24399                     Benign  1.547156e+09         NaN
# ...

# %%
zeek = pd.read_csv('./zeek.csv')
zeek
# Out:
#                   ts                 uid       id.orig_h  id.orig_p  \
# 0       1.526756e+09  C9YvmJ3zxtuqxWxLW5     192.168.2.5      38792
# 1       1.526756e+09  CGsZqZ3UiQexLzPRVb     192.168.2.5      38792
# 2       1.526756e+09  C0LkBW2VEa292Nvet8     192.168.2.5      38793
# 3       1.526756e+09  CMDLrn2cVhrqvW8gKa     192.168.2.5      38793
# 4       1.526756e+09  C2UM8f4knuL5Vnvp3h     192.168.2.5      38794
# ...              ...                 ...             ...        ...
# 200566  1.547156e+09  Cg18Jr15pQhdJUELL4   192.168.1.197        123
# 200567  1.547156e+09  CF56fv3yDg2vRnegKa   192.168.1.197        123
# 200568  1.547157e+09  Ccvd9l4NjDPEkD1nRd   192.168.1.197        123
# 200569  1.547127e+09  C07GbT1HxlFUEjwiNh  185.244.25.183       4975
# 200570  1.547157e+09  Cb4VXV3tOHGjcsI0cf   192.168.1.197        123
#
#              id.resp_h  id.resp_p proto service     duration orig_bytes  ...  \
# ...

# %%
all = pd.merge(pcap, zeek, how='left', left_on=['ts'], right_on='ts')
all[all["ip_version"]==4]
all = all[['detailed_label','ip_tos','ip_len', 'ip_id', 'ip_flags', 'ip_ttl', 'ip_proto','tcp_sport', 'tcp_dport', 'tcp_seq','tcp_ack', 'tcp_dataofs','tcp_flags', 'tcp_window','tcp_chksum','udp_sport', 'udp_dport', 'udp_len','id.orig_p', 'id.resp_p', 'proto', 'service', 'duration','orig_bytes', 'resp_bytes', 'conn_state', 'local_resp','missed_bytes', 'history', 'orig_pkts', 'orig_ip_bytes', 'resp_pkts','resp_ip_bytes']]
all.to_csv('all.csv')

# %%
all.columns
# Out:
# Index(['detailed_label', 'ip_tos', 'ip_len', 'ip_id', 'ip_flags', 'ip_ttl',
#        'ip_proto', 'tcp_sport', 'tcp_dport', 'tcp_seq', 'tcp_ack',
#        'tcp_dataofs', 'tcp_flags', 'tcp_window', 'tcp_chksum', 'udp_sport',
#        'udp_dport', 'udp_len', 'id.orig_p', 'id.resp_p', 'proto', 'service',
#        'duration', 'orig_bytes', 'resp_bytes', 'conn_state', 'local_resp',
#        'missed_bytes', 'history', 'orig_pkts', 'orig_ip_bytes', 'resp_pkts',
#        'resp_ip_bytes'],
#       dtype='object')

# %%
all = pd.merge(pcap, zeek, how='left', left_on=['ts'], right_on='ts')
all[all["ip_version"]==4]

# all = all['detailed_label','ip_tos','ip_len', 'ip_id', 'ip_flags', 'ip_ttl', 'ip_proto','tcp_sport', 'tcp_dport', 'tcp_seq','tcp_ack', 'tcp_dataofs','tcp_flags', 'tcp_window','tcp_chksum','udp_sport', 'udp_dport', 'udp_len','id.orig_p',  'id.resp_p', 'proto', 'service', 'duration','orig_bytes', 'resp_bytes', 'conn_state', 'local_orig', 'local_resp','missed_bytes', 'history', 'orig_pkts', 'orig_ip_bytes', 'resp_pkts','resp_ip_bytes',  'detailed-label']
all
# Out:
#                    detailed_label  ip_tos  ip_len    ip_id ip_flags  ip_ttl  \
# 0                          Benign   192.0    76.0  25997.0       DF    64.0
# 1                          Benign   192.0    76.0   3940.0       DF    64.0
# 2                          Benign   192.0    76.0   6403.0       DF    64.0
# 3                          Benign    16.0    88.0  53617.0      NaN    64.0
# 4       PartOfAHorizontalPortScan     0.0    60.0  12497.0       DF    64.0
# ...                           ...     ...     ...      ...      ...     ...
# 200581                     Benign     NaN     NaN      NaN      NaN     NaN
# 200582                     Benign     0.0    77.0  10289.0       DF    64.0
# 200583                     Benign     NaN     NaN      NaN      NaN     NaN
# 200584                     Benign     NaN     NaN      NaN      NaN     NaN
# 200585                     Benign   164.0    78.0  24685.0       DF    49.0
#
# ...
